# %% [markdown]
# <a href="https://colab.research.google.com/github/HinataKikuchi/Governor-of-Tokyo-Cup/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
import io

URL = "http://www.toshiseibi.metro.tokyo.jp/bosai/data/mokuzou2.csv" # ここにcsvファイルのURLを書く
r = requests.get(URL)
df = pd.read_csv(io.BytesIO(r.content),encoding='shift-jis',sep=",")

# %%
df
# Out:
#        区  番号               地区名  面積(ha)          事業期間
# 0    新宿区   1            若葉・須賀町    15.6   平成5年度〜令和6年度
# 1    台東区   2         谷中二・三・五丁目    28.7  平成14年度〜令和7年度
# 2    墨田区   3              北部中央   184.5  昭和59年度〜令和7年度
# 3    墨田区   4                京島    25.5  昭和58年度〜令和7年度
# 4    墨田区   5             鐘ヶ淵周辺    80.6  平成18年度〜令和7年度
# 5    江東区   6         北砂三・四・五丁目    48.6  平成26年度〜令和7年度
# 6    品川区   7            旗の台・中延    19.3   平成3年度〜令和6年度
# 7    品川区   8    二葉三・四丁目、西大井六丁目    34.2  平成18年度〜令和7年度
# 8    品川区   9  東中延一・二丁目、中延二・三丁目    29.4  平成19年度〜令和7年度
# 9    品川区  10         豊町四・五・六丁目    29.4  平成19年度〜令和7年度
# 10   品川区  11          西品川二・三丁目    27.7  平成30年度〜令和9年度
# 11   品川区  12             戸越六丁目    13.0  令和3年度〜令和12年度
# 12   目黒区  13           目黒本町・原町    61.0   平成3年度〜令和7年度
# 13   大田区  14                羽田    50.4  平成26年度〜令和5年度
# 14  世田谷区  15            太子堂・三宿    80.7  平成18年度〜令和7年度
# 15  世田谷区  16           北沢三・四丁目    33.6    平成元年〜令和7年度
# 16  世田谷区  17            世田谷・若林    47.7   平成3年度〜令和7年度
# ...
